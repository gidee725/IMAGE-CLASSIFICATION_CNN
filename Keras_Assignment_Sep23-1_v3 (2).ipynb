# %% [markdown]
# # Applied Data Science 2 - Keras Assignment - 2023A
#
# In this assignment you will be building a script to classify images of animals. The assignment is broken up into sections and you need to complete each section successively. The sections are:
#
# 1. Data Processing
# 2. Model Definition
# 3. Model Training
# 4. Model Evaluation
#
# In addition to this coding exercise, you will also need to write a 1-2 page report analysing and critically evaluating you models results.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib

from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Data Processing

# %%
# CodeGrade Tag DataProc

label_dict = {'cat' : 0,
              'dog' : 1,
              'wild' : 2}

# This function is provided to read in the image files from the folder on your
# Google Drive
def parse_image(filename):
    parts = tf.strings.split(filename, os.sep)
    label = parts[-2]
    label = tf.strings.to_number(label)

    image = tf.io.read_file(filename)
    image = tf.io.decode_jpeg(image)
    return image, label


img_loc = "/content/drive/MyDrive/Animals/"

train_list_ds = tf.data.Dataset.list_files(img_loc + "train/*/*")
valid_list_ds = tf.data.Dataset.list_files(img_loc + "val/*/*")

# %% [markdown]
# **Create a function called "img_process" converts the images to float32 datatype and resizes them to 64x64 pixels.**

# %%
# CodeGrade Tag Ex1a
### Write a function called img_process, which takes in the image and label as
### inputs, converts the data type of the image to tf.float32, resizes the
### image to (64,64), and finally returns the image and labels.

def img_process(image, label):
    # Converting image data type to tf.float32
    image = tf.image.convert_image_dtype(image, tf.float32)

    # Resizing the image to (64, 64)
    image = tf.image.resize(image, [64, 64], method='bilinear')

    return image, label

# %% [markdown]
# **Using the tf.data API, load in the training and validation data. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1b
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 128. Use techniques like caching and
### prefetching to efficiently load the data.

# loading and preprocessing the training data
train_ds = train_list_ds.map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.cache().batch(128).prefetch(tf.data.AUTOTUNE)
# loading and preprocessing the validation data
valid_ds = valid_list_ds.map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
valid_ds = valid_ds.map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
valid_ds = valid_ds.cache().batch(128).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # Model Definition
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture show in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a SoftMax activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        1216
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 10)                5130
#
# =================================================================
# Total params: 363146 (1.39 MB)
# Trainable params: 363146 (1.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# Defining the input layer
inputs = Input(shape=(64, 64, 3), name='Input')

# Defining the convolutional layers
x = Conv2D(16, (3, 3), strides=(2, 2), padding='same', activation='relu', name='Conv0')(inputs)
x = Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv1')(x)
x = Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv2')(x)

# Defining the first pooling layer
x = MaxPooling2D((2, 2), name='Pool1')(x)

# Defining the next convolutional layers
x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv3')(x)
x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv4')(x)

# Defininge the second pooling layer
x = MaxPooling2D((2, 2), name='Pool2')(x)

# Defining the last convolutional layers
x = Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv5')(x)
x = Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv6')(x)

# Defining the global average pooling layer
x = GlobalAveragePooling2D(name='GlobalPool')(x)

# Defining the dense layers
x = Dense(512, activation='relu', name='FC1')(x)
outputs = Dense(3, activation='softmax', name='Output')(x)

# Creating the model
model = Model(inputs=inputs, outputs=outputs, name='model')

# %%
# CodeGrade Tag Ex2b
### Print the model summary and confirm is has the same architecture as the one
### provided.
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 3)                 1539
#
# =================================================================
# Total params: 358787 (1.37 MB)
# Trainable params: 358787 (1.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Compile the model using the Adam Optimizer with a learning rate of ```5e-5```, ```sparse categorical crossentropy``` loss function, and ```accuracy``` metric.**

# %%
# CodeGrade Tag Ex2c

from tensorflow.keras.optimizers import Adam

# Compile the model
model.compile(optimizer=Adam(learning_rate=5e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Model Training
#
# **Create a Model Checkpoint Callback that saves the weights of the best performing epoch, based on the validation accuracy.**

# %%
# CodeGrade Tag Ex3a
### Create a ModelCheckpoint callback to store the bext weights from the model,
### based on the validation accuracy. Call this callback "checkpoint_callback"

# Defining the checkpoint file path
checkpoint_filepath = "/content/checkpoint"

checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1,
    save_weights_only=True,
    )

# %% [markdown]
# **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3b
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"
from tensorflow.keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.01)

from tensorflow.keras.callbacks import LearningRateScheduler

# Creating a LearningRateScheduler callback
lr_callback = LearningRateScheduler(scheduler, verbose=1)

# %% [markdown]
# **Train the model for 100 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3c
### Train the model for 100 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

# Training the model for 100 epochs
history = model.fit(train_ds,
                    epochs=100,
                    validation_data=valid_ds,
                    callbacks=[checkpoint_callback, lr_callback])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 1/100
# 115/115 [==============================] - ETA: 0s - loss: 1.4782 - accuracy: 0.3434
# Epoch 1: val_accuracy improved from -inf to 0.35000, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 169s 1s/step - loss: 1.4782 - accuracy: 0.3434 - val_loss: 1.0957 - val_accuracy: 0.3500 - lr: 5.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 2/100
# 115/115 [==============================] - ETA: 0s - loss: 1.0746 - accuracy: 0.4132
# Epoch 2: val_accuracy improved from 0.35000 to 0.42067, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 134s 1s/step - loss: 1.0746 - accuracy: 0.4132 - val_loss: 1.0557 - val_accuracy: 0.4207 - lr: 5.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 3/100
# 115/115 [==============================] - ETA: 0s - loss: 0.9813 - accuracy: 0.5013
# Epoch 3: val_accuracy improved from 0.42067 to 0.56133, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 171s 1s/step - loss: 0.9813 - accuracy: 0.5013 - val_loss: 0.9445 - val_accuracy: 0.5613 - lr: 5.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 4/100
# 115/115 [==============================] - ETA: 0s - loss: 0.9060 - accuracy: 0.5520
# Epoch 4: val_accuracy improved from 0.56133 to 0.61000, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 126s 1s/step - loss: 0.9060 - accuracy: 0.5520 - val_loss: 0.8700 - val_accuracy: 0.6100 - lr: 5.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 5/100
# 115/115 [==============================] - ETA: 0s - loss: 0.8519 - accuracy: 0.5804
# Epoch 5: val_accuracy improved from 0.61000 to 0.62800, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 863ms/step - loss: 0.8519 - accuracy: 0.5804 - val_loss: 0.8221 - val_accuracy: 0.6280 - lr: 5.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 6/100
# 115/115 [==============================] - ETA: 0s - loss: 0.8175 - accuracy: 0.6038
# Epoch 6: val_accuracy improved from 0.62800 to 0.63533, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 105s 912ms/step - loss: 0.8175 - accuracy: 0.6038 - val_loss: 0.7914 - val_accuracy: 0.6353 - lr: 5.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 7/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7889 - accuracy: 0.6257
# Epoch 7: val_accuracy improved from 0.63533 to 0.65200, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 102s 885ms/step - loss: 0.7889 - accuracy: 0.6257 - val_loss: 0.7619 - val_accuracy: 0.6520 - lr: 5.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 8/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7583 - accuracy: 0.6506
# Epoch 8: val_accuracy improved from 0.65200 to 0.66733, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 858ms/step - loss: 0.7583 - accuracy: 0.6506 - val_loss: 0.7318 - val_accuracy: 0.6673 - lr: 5.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 9/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7318 - accuracy: 0.6628
# Epoch 9: val_accuracy improved from 0.66733 to 0.68533, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 97s 847ms/step - loss: 0.7318 - accuracy: 0.6628 - val_loss: 0.7074 - val_accuracy: 0.6853 - lr: 5.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 10/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7069 - accuracy: 0.6755
# Epoch 10: val_accuracy improved from 0.68533 to 0.69200, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 101s 876ms/step - loss: 0.7069 - accuracy: 0.6755 - val_loss: 0.6878 - val_accuracy: 0.6920 - lr: 5.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to
-05
#
# Epoch 46: LearningRateScheduler setting learning rate to 3.488381844363175e-05.
# Epoch 46/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.8317
# Epoch 46: val_accuracy improved from 0.81400 to 0.81600, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 859ms/step - loss: 0.4219 - accuracy: 0.8317 - val_loss: 0.4377 - val_accuracy: 0.8160 - lr: 3.4884e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 3.453671888564713e-05.
# Epoch 47/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4178 - accuracy: 0.8334
# Epoch 47: val_accuracy did not improve from 0.81600
# 115/115 [==============================] - 98s 855ms/step - loss: 0.4178 - accuracy: 0.8334 - val_loss: 0.4339 - val_accuracy: 0.8160 - lr: 3.4537e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 3.419307176955044e-05.
# Epoch 48/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 0.8354
# Epoch 48: val_accuracy improved from 0.81600 to 0.81800, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 100s 868ms/step - loss: 0.4138 - accuracy: 0.8354 - val_loss: 0.4303 - val_accuracy: 0.8180 - lr: 3.4193e-05
#
# Epoch 49: LearningRateScheduler setting learning rate to 3.385284435353242e-05.
# Epoch 49/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4099 - accuracy: 0.8370
# Epoch 49: val_accuracy improved from 0.81800 to 0.81933, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 98s 852ms/step - loss: 0.4099 - accuracy: 0.8370 - val_loss: 0.4263 - val_accuracy: 0.8193 - lr: 3.3853e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 3.35160038957838e-05.
# Epoch 50/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.8386
# Epoch 50: val_accuracy improved from 0.81933 to 0.82267, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 858ms/step - loss: 0.4060 - accuracy: 0.8386 - val_loss: 0.4229 - val_accuracy: 0.8227 - lr: 3.3516e-05
#
# Epoch 51: LearningRateScheduler setting learning rate to 3.318251401651651e-05.
# Epoch 51/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4023 - accuracy: 0.8409
# Epoch 51: val_accuracy improved from 0.82267 to 0.82400, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 97s 846ms/step - loss: 0.4023 - accuracy: 0.8409 - val_loss: 0.4189 - val_accuracy: 0.8240 - lr: 3.3183e-05
#
# Epoch 52: LearningRateScheduler setting learning rate to 3.2852341973921284e-05.
# Epoch 52/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3984 - accuracy: 0.8425
# Epoch 52: val_accuracy improved from 0.82400 to 0.82533, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 98s 852ms/step - loss: 0.3984 - accuracy: 0.8425 - val_loss: 0.4150 - val_accuracy: 0.8253 - lr: 3.2852e-05
#
# Epoch 53: LearningRateScheduler setting learning rate to 3.2525455026188865e-05.
# Epoch 53/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.8440
# Epoch 53: val_accuracy improved from 0.82533 to 0.82733, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 98s 855ms/step - loss: 0.3945 - accuracy: 0.8440 - val_loss: 0.4107 - val_accuracy: 0.8273 - lr: 3.2525e-05
#
# Epoch 54: LearningRateScheduler setting learning rate to 3.2201820431509987e-05.
# Epoch 54/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3909 - accuracy: 0.8455
# Epoch 54: val_accuracy improved from 0.82733 to 0.82867, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 97s 846ms/step - loss: 0.3909 - accuracy: 0.8455 - val_loss: 0.4070 - val_accuracy: 0.8287 - lr: 3.2202e-05
#
# Epoch 55: LearningRateScheduler setting learning rate to 3.1881405448075384e-05.
# Epoch 55/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3872 - accuracy: 0.8471
# Epoch 55: val_accuracy improved from 0.82867 to 0.83067, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 96s 836ms/step - loss: 0.3872 - accuracy: 0.8471 - val_loss: 0.4033 - val_accuracy: 0.8307 - lr: 3.1881e-05
#
# Epoch 56: LearningRateScheduler setting learning rate to 3.15641809720546e-05.
# Epoch 56/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3837 - accuracy: 0.8490
# Epoch 56: val_accuracy improved from 0.83067 to 0.83667, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 95s 830ms/step - loss: 0.3837 - accuracy: 0.8490 - val_loss: 0.3992 - val_accuracy: 0.8367 - lr: 3.1564e-05
#
# Epoch 57: LearningRateScheduler setting learning rate to 3.1250110623659566e-05.
# Epoch 57/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3803 - accuracy: 0.8505
# Epoch 57: val_accuracy improved from 0.83667 to 0.84000, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 859ms/step - loss: 0.3803 - accuracy: 0.8505 - val_loss: 0.3956 - val_accuracy: 0.8400 - lr: 3.1250e-05
#
# Epoch 58: LearningRateScheduler setting learning rate to 3.093916529905982e-05.
# Epoch 58/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.8518
# Epoch 58: val_accuracy improved from 0.84000 to 0.84400, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 861ms/step - loss: 0.3768 - accuracy: 0.8518 - val_loss: 0.3913 - val_accuracy: 0.8440 - lr: 3.0939e-05
#
# Epoch 59: LearningRateScheduler setting learning rate to 3.0631315894424915e-05.
# Epoch 59/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3735 - accuracy: 0.8532
# Epoch 59: val_accuracy improved from 0.84400 to 0.84467, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 98s 854ms/step - loss: 0.3735 - accuracy: 0.8532 - val_loss: 0.3879 - val_accuracy: 0.8447 - lr: 3.0631e-05
#
# Epoch 60: LearningRateScheduler setting learning rate to 3.032652966794558e-05.
# Epoch 60/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3703 - accuracy: 0.8548
# Epoch 60: val_accuracy improved from 0.84467 to 0.84733, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 858ms/step - loss: 0.3703 - accuracy: 0.8548 - val_loss: 0.3842 - val_accuracy: 0.8473 - lr: 3.0327e-05
#
# Epoch 61: LearningRateScheduler setting learning rate to 3.0024775696801953e-05.
# Epoch 61/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8566
# Epoch 61: val_accuracy improved from 0.84733 to 0.84933, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 858ms/step - loss: 0.3673 - accuracy: 0.8566 - val_loss: 0.3806 - val_accuracy: 0.8493 - lr: 3.0025e-05
#
# Epoch 62: LearningRateScheduler setting learning rate to 2.972602487716358e-05.
# Epoch 62/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8585
# Epoch 62: val_accuracy improved from 0.84933 to 0.85133, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 98s 850ms/step - loss: 0.3641 - accuracy: 0.8585 - val_loss: 0.3765 - val_accuracy: 0.8513 - lr: 2.9726e-05
#
# Epoch 63: LearningRateScheduler setting learning rate to 2.9430246286210604e-05.
# Epoch 63/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3610 - accuracy: 0.8600
# Epoch 63: val_accuracy improved from 0.85133 to 0.85267, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 97s 841ms/step - loss: 0.3610 - accuracy: 0.8600 - val_loss: 0.3729 - val_accuracy: 0.8527 - lr: 2.9430e-05
#
# Epoch 64: LearningRateScheduler setting learning rate to 2.9137410820112564e-05.
# Epoch 64/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3580 - accuracy: 0.8613
# Epoch 64: val_accuracy improved from 0.85267 to 0.85667, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 96s 832ms/step - loss: 0.3580 - accuracy: 0.8613 - val_loss: 0.3692 - val_accuracy: 0.8567 - lr: 2.9137e-05
#
# Epoch 65: LearningRateScheduler setting learning rate to 2.8847489375039004e-05.
# Epoch 65/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.8630
# Epoch 65: val_accuracy improved from 0.85667 to 0.85933, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 95s 828ms/step - loss: 0.3550 - accuracy: 0.8630 - val_loss: 0.3653 - val_accuracy: 0.8593 - lr: 2.8847e-05
#
# Epoch 66: LearningRateScheduler setting learning rate to 2.8560452847159468e-05.
# Epoch 66/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3520 - accuracy: 0.8644
# Epoch 66: val_accuracy improved from 0.85933 to 0.86067, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 96s 832ms/step - loss: 0.3520 - accuracy: 0.8644 - val_loss: 0.3616 - val_accuracy: 0.8607 - lr: 2.8560e-05
#
# Epoch 67: LearningRateScheduler setting learning rate to 2.82762721326435e-05.
# Epoch 67/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.8651
# Epoch 67: val_accuracy improved from 0.86067 to 0.86200, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 95s 826ms/step - loss: 0.3492 - accuracy: 0.8651 - val_loss: 0.3587 - val_accuracy: 0.8620 - lr: 2.8276e-05
#
# Epoch 68: LearningRateScheduler setting learning rate to 2.799491812766064e-05.
# Epoch 68/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8660
# Epoch 68: val_accuracy improved from 0.86200 to 0.86267, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 96s 837ms/step - loss: 0.3464 - accuracy: 0.8660 - val_loss: 0.3560 - val_accuracy: 0.8627 - lr: 2.7995e-05
#
# Epoch 69: LearningRateScheduler setting learning rate to 2.7716363547369838e-05.
# Epoch 69/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8672
# Epoch 69: val_accuracy improved from 0.86267 to 0.86467, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 96s 833ms/step - loss: 0.3437 - accuracy: 0.8672 - val_loss: 0.3528 - val_accuracy: 0.8647 - lr: 2.7716e-05
#
# Epoch 70: LearningRateScheduler setting learning rate to 2.744058110693004e-05.
# Epoch 70/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3410 - accuracy: 0.8680
# Epoch 70: val_accuracy improved from 0.86467 to 0.86667, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 95s 826ms/step - loss: 0.3410 - accuracy: 0.8680 - val_loss: 0.3497 - val_accuracy: 0.8667 - lr: 2.7441e-05
#
# Epoch 71: LearningRateScheduler setting learning rate to 2.7167543521500193e-05.
# Epoch 71/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.8694
# Epoch 71: val_accuracy improved from 0.86667 to 0.86867, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 96s 834ms/step - loss: 0.3384 - accuracy: 0.8694 - val_loss: 0.3468 - val_accuracy: 0.8687 - lr: 2.7168e-05
#
# Epoch 72: LearningRateScheduler setting learning rate to 2.689722168724984e-05.
# Epoch 72/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3359 - accuracy: 0.8703
# Epoch 72: val_accuracy did not improve from 0.86867
# 115/115 [==============================] - 95s 831ms/step - loss: 0.3359 - accuracy: 0.8703 - val_loss: 0.3442 - val_accuracy: 0.8687 - lr: 2.6897e-05
#
# Epoch 73: LearningRateScheduler setting learning rate to 2.662959013832733e-05.
# Epoch 73/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3333 - accuracy: 0.8721
# Epoch 73: val_accuracy improved from 0.86867 to 0.87200, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 106s 926ms/step - loss: 0.3333 - accuracy: 0.8721 - val_loss: 0.3413 - val_accuracy: 0.8720 - lr: 2.6630e-05
#
# Epoch 74: LearningRateScheduler setting learning rate to 2.6364621589891613e-05.
# Epoch 74/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3308 - accuracy: 0.8732
# Epoch 74: val_accuracy improved from 0.87200 to 0.87333, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 101s 879ms/step - loss: 0.3308 - accuracy: 0.8732 - val_loss: 0.3386 - val_accuracy: 0.8733 - lr: 2.6365e-05
#
# Epoch 75: LearningRateScheduler setting learning rate to 2.6102288757101633e-05.
# Epoch 75/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3285 - accuracy: 0.8741
# Epoch 75: val_accuracy improved from 0.87333 to 0.87533, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 859ms/step - loss: 0.3285 - accuracy: 0.8741 - val_loss: 0.3363 - val_accuracy: 0.8753 - lr: 2.6102e-05
#
# Epoch 76: LearningRateScheduler setting learning rate to 2.584256617410574e-05.
# Epoch 76/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.8752
# Epoch 76: val_accuracy did not improve from 0.87533
# 115/115 [==============================] - 99s 860ms/step - loss: 0.3262 - accuracy: 0.8752 - val_loss: 0.3341 - val_accuracy: 0.8753 - lr: 2.5843e-05
#
# Epoch 77: LearningRateScheduler setting learning rate to 2.5585428375052288e-05.
# Epoch 77/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.8755
# Epoch 77: val_accuracy improved from 0.87533 to 0.87600, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 863ms/step - loss: 0.3240 - accuracy: 0.8755 - val_loss: 0.3322 - val_accuracy: 0.8760 - lr: 2.5585e-05
#
# Epoch 78: LearningRateScheduler setting learning rate to 2.5330849894089624e-05.
# Epoch 78/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.8761
# Epoch 78: val_accuracy improved from 0.87600 to 0.87667, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 98s 856ms/step - loss: 0.3218 - accuracy: 0.8761 - val_loss: 0.3304 - val_accuracy: 0.8767 - lr: 2.5331e-05
#
# Epoch 79: LearningRateScheduler setting learning rate to 2.5078803446376696e-05.
# Epoch 79/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.8770
# Epoch 79: val_accuracy improved from 0.87667 to 0.87800, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 860ms/step - loss: 0.3197 - accuracy: 0.8770 - val_loss: 0.3286 - val_accuracy: 0.8780 - lr: 2.5079e-05
#
# Epoch 80: LearningRateScheduler setting learning rate to 2.4829265385051258e-05.
# Epoch 80/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.8775
# Epoch 80: val_accuracy improved from 0.87800 to 0.87933, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 97s 842ms/step - loss: 0.3177 - accuracy: 0.8775 - val_loss: 0.3269 - val_accuracy: 0.8793 - lr: 2.4829e-05
#
# Epoch 81: LearningRateScheduler setting learning rate to 2.458221024426166e-05.
# Epoch 81/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8786
# Epoch 81: val_accuracy did not improve from 0.87933
# 115/115 [==============================] - 95s 830ms/step - loss: 0.3157 - accuracy: 0.8786 - val_loss: 0.3254 - val_accuracy: 0.8793 - lr: 2.4582e-05
#
# Epoch 82: LearningRateScheduler setting learning rate to 2.4337612558156252e-05.
# Epoch 82/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.8798
# Epoch 82: val_accuracy did not improve from 0.87933
# 115/115 [==============================] - 95s 827ms/step - loss: 0.3138 - accuracy: 0.8798 - val_loss: 0.3232 - val_accuracy: 0.8793 - lr: 2.4338e-05
#
# Epoch 83: LearningRateScheduler setting learning rate to 2.409544867987279e-05.
# Epoch 83/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8809
# Epoch 83: val_accuracy improved from 0.87933 to 0.88000, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 96s 831ms/step - loss: 0.3119 - accuracy: 0.8809 - val_loss: 0.3217 - val_accuracy: 0.8800 - lr: 2.4095e-05
#
# Epoch 84: LearningRateScheduler setting learning rate to 2.3855694962549023e-05.
# Epoch 84/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3100 - accuracy: 0.8811
# Epoch 84: val_accuracy did not improve from 0.88000
# 115/115 [==============================] - 96s 834ms/step - loss: 0.3100 - accuracy: 0.8811 - val_loss: 0.3197 - val_accuracy: 0.8793 - lr: 2.3856e-05
#
# Epoch 85: LearningRateScheduler setting learning rate to 2.361832775932271e-05.
# Epoch 85/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3082 - accuracy: 0.8819
# Epoch 85: val_accuracy did not improve from 0.88000
# 115/115 [==============================] - 96s 835ms/step - loss: 0.3082 - accuracy: 0.8819 - val_loss: 0.3176 - val_accuracy: 0.8793 - lr: 2.3618e-05
#
# Epoch 86: LearningRateScheduler setting learning rate to 2.33833216043422e-05.
# Epoch 86/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.8832
# Epoch 86: val_accuracy improved from 0.88000 to 0.88067, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 861ms/step - loss: 0.3065 - accuracy: 0.8832 - val_loss: 0.3161 - val_accuracy: 0.8807 - lr: 2.3383e-05
#
# Epoch 87: LearningRateScheduler setting learning rate to 2.315065466973465e-05.
# Epoch 87/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 0.8833
# Epoch 87: val_accuracy improved from 0.88067 to 0.88400, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 100s 869ms/step - loss: 0.3048 - accuracy: 0.8833 - val_loss: 0.3136 - val_accuracy: 0.8840 - lr: 2.3151e-05
#
# Epoch 88: LearningRateScheduler setting learning rate to 2.292030148964841e-05.
# Epoch 88/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3031 - accuracy: 0.8845
# Epoch 88: val_accuracy did not improve from 0.88400
# 115/115 [==============================] - 99s 857ms/step - loss: 0.3031 - accuracy: 0.8845 - val_loss: 0.3115 - val_accuracy: 0.8840 - lr: 2.2920e-05
#
# Epoch 89: LearningRateScheduler setting learning rate to 2.2692240236210637e-05.
# Epoch 89/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3016 - accuracy: 0.8847
# Epoch 89: val_accuracy improved from 0.88400 to 0.88667, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 101s 875ms/step - loss: 0.3016 - accuracy: 0.8847 - val_loss: 0.3095 - val_accuracy: 0.8867 - lr: 2.2692e-05
#
# Epoch 90: LearningRateScheduler setting learning rate to 2.246644908154849e-05.
# Epoch 90/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.8859
# Epoch 90: val_accuracy improved from 0.88667 to 0.88933, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 100s 866ms/step - loss: 0.3000 - accuracy: 0.8859 - val_loss: 0.3072 - val_accuracy: 0.8893 - lr: 2.2466e-05
#
# Epoch 91: LearningRateScheduler setting learning rate to 2.224290437879972e-05.
# Epoch 91/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2986 - accuracy: 0.8866
# Epoch 91: val_accuracy did not improve from 0.88933
# 115/115 [==============================] - 98s 854ms/step - loss: 0.2986 - accuracy: 0.8866 - val_loss: 0.3050 - val_accuracy: 0.8893 - lr: 2.2243e-05
#
# Epoch 92: LearningRateScheduler setting learning rate to 2.202158430009149e-05.
# Epoch 92/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.8877
# Epoch 92: val_accuracy improved from 0.88933 to 0.89200, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 98s 852ms/step - loss: 0.2972 - accuracy: 0.8877 - val_loss: 0.3026 - val_accuracy: 0.8920 - lr: 2.2022e-05
#
# Epoch 93: LearningRateScheduler setting learning rate to 2.180246519856155e-05.
# Epoch 93/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2959 - accuracy: 0.8886
# Epoch 93: val_accuracy did not improve from 0.89200
# 115/115 [==============================] - 96s 835ms/step - loss: 0.2959 - accuracy: 0.8886 - val_loss: 0.3002 - val_accuracy: 0.8920 - lr: 2.1802e-05
#
# Epoch 94: LearningRateScheduler setting learning rate to 2.158552706532646e-05.
# Epoch 94/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8887
# Epoch 94: val_accuracy improved from 0.89200 to 0.89333, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 95s 826ms/step - loss: 0.2946 - accuracy: 0.8887 - val_loss: 0.2978 - val_accuracy: 0.8933 - lr: 2.1586e-05
#
# Epoch 95: LearningRateScheduler setting learning rate to 2.137074807251338e-05.
# Epoch 95/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2933 - accuracy: 0.8893
# Epoch 95: val_accuracy did not improve from 0.89333
# 115/115 [==============================] - 96s 835ms/step - loss: 0.2933 - accuracy: 0.8893 - val_loss: 0.2953 - val_accuracy: 0.8933 - lr: 2.1371e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 2.1158106392249465e-05.
# Epoch 96/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8898
# Epoch 96: val_accuracy did not improve from 0.89333
# 115/115 [==============================] - 96s 831ms/step - loss: 0.2921 - accuracy: 0.8898 - val_loss: 0.2928 - val_accuracy: 0.8933 - lr: 2.1158e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 2.0947580196661875e-05.
# Epoch 97/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2909 - accuracy: 0.8904
# Epoch 97: val_accuracy improved from 0.89333 to 0.89400, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 99s 859ms/step - loss: 0.2909 - accuracy: 0.8904 - val_loss: 0.2903 - val_accuracy: 0.8940 - lr: 2.0948e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 2.0739147657877766e-05.
# Epoch 98/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8908
# Epoch 98: val_accuracy improved from 0.89400 to 0.89667, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 103s 897ms/step - loss: 0.2896 - accuracy: 0.8908 - val_loss: 0.2879 - val_accuracy: 0.8967 - lr: 2.0739e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 2.0532790586003102e-05.
# Epoch 99/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8914
# Epoch 99: val_accuracy improved from 0.89667 to 0.89733, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 100s 872ms/step - loss: 0.2885 - accuracy: 0.8914 - val_loss: 0.2855 - val_accuracy: 0.8973 - lr: 2.0533e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 2.032848533417564e-05.
# Epoch 100/100
# 115/115 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.8919
# Epoch 100: val_accuracy improved from 0.89733 to 0.89933, saving model to D:/contents/content\checkpoint
# 115/115 [==============================] - 98s 855ms/step - loss: 0.2874 - accuracy: 0.8919 - val_loss: 0.2835 - val_accuracy: 0.8993 - lr: 2.0328e-05

# %% [markdown]
# # Model Evaluation
#
# **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the models performance.**

# %%
# CodeGrade Tag Ex4a
# Train the model for 100 epochs
# Plotting training & validation accuracy values
import matplotlib.pyplot as plt

# Plotting training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Load the best weights from your model checkpoint, and create plots demonstrating the classification perfomnce for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %%
# CodeGrade Tag Ex4b

# Loading the best weights
model.load_weights( "/content/checkpoint"
                  
                  )

# %%
#defining the test dataset
validation_images, validation_labels = next(iter(valid_ds)) 
 # Making predictions using the model
y_pred = model.predict(validation_images)

# defining the labels
Labels = ["Cats", "Dogs", "Wild"]
# Converting the predictions from class probabilities to class labels
preds_lables = np.argmax(y_pred, axis=1)

# Printing the classification report
print('classification Report')
print(classification_report(validation_labels, preds_lables, target_names=Labels))

# plotting  the confusion matrix
cm = confusion_matrix(validation_labels, preds_lables)


# Plotting the confusion matrix
sns.heatmap(cm, annot=True, fmt='d',  xticklabels=Labels, cmap='Blues')
# Out:
# 4/4 [==============================] - 0s 56ms/step
# classification Report
#               precision    recall  f1-score   support
#
#         Cats       0.88      0.95      0.92        40
#         Dogs       0.94      0.90      0.92        49
#         Wild       0.92      0.90      0.91        39
#
#     accuracy                           0.91       128
#    macro avg       0.91      0.92      0.91       128
# weighted avg       0.92      0.91      0.91       128
# <Axes: >
